# %% [markdown]
# # Try changing the labels to [0 0.25 0.5 1]
# ## I don't think is actually necessary to make a prob of this one. The results are not that promising and don't work for everyone.

# %%
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout, TimeDistributed, BatchNormalization, Flatten, Activation
from keras import regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import numpy as np
import h5py
import matplotlib.pyplot as plt
from data_utils import get_data
from sklearn import preprocessing
from functools import reduce
from scipy.fftpack import dct, idct
from scipy import signal

from Code.data_loaders import load_data_labels_based_on_dataset
from share import datasets_basic_infos
from Code.data_utils import train_test_val_split

# %%
# Load data from all .mat files, combine them, eliminate EOG signals, shuffle and
# seperate training data, validation data and testing data.
# Also do mean subtraction on x.


subject_id = 3  # Only two things I should be able to change
dataset_name = 'aguilera_gamified'  # Only two things I should be able to change

# Folders and paths
dataset_foldername = dataset_name + '_dataset'
data_path = "/Users/almacuevas/work_projects/voting_system_platform/Datasets/" + dataset_foldername
dataset_info = datasets_basic_infos[dataset_name]

data, label = load_data_labels_based_on_dataset(dataset_name, subject_id, data_path, array_format=True)
# Out:
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 55 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 55.00 Hz
# - Upper transition bandwidth: 13.75 Hz (-6 dB cutoff frequency: 61.88 Hz)
# - Filter length: 1651 samples (3.302 s)
#
# Used Annotations descriptions: ['OVTK_StimulationId_EndOfFile', 'OVTK_StimulationId_Number_01', 'OVTK_StimulationId_Number_02', 'OVTK_StimulationId_Number_03', 'OVTK_StimulationId_Number_04', 'OVTK_StimulationId_Number_05', 'OVTK_StimulationId_Number_06', 'OVTK_StimulationId_Number_07', 'OVTK_StimulationId_Number_08']
# Not setting metadata
# 120 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 120 events and 701 original time points ...
# 0 bad epochs dropped
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s

# %%
# substract data from list
X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(dataX = data, dataY= label, valid_flag=True)

# get data dimension
N_train, T_train, C_train = X_train.shape
N_val, T_val, C_val = X_val.shape
N_test, T_test, C_test = X_test.shape

# add dummy zeros for y classification
lb = preprocessing.LabelBinarizer()
lb.fit([0, 1, 2, 3,])
lb.classes_
y_train = lb.transform(y_train)
if (N_val > 0): y_val = lb.transform(y_val)
y_test = lb.transform(y_test)

# %%
# Filtering through FFT(discrete cosine transform)

def filter(x, low=0, high=1, plot=False):
    N = x.shape[0]
    t = np.linspace(0,N,N)
    y = dct(x, norm='ortho')
    window = np.zeros(N)
    window[int(low*N):int(high*N)] = 1
    yr = idct(y*window, norm='ortho')
    sum(abs(x-yr)**2) / sum(abs(x)**2)
    if plot:
        plt.plot(t, x, '-b')
        plt.plot(t, yr, 'r')
    return x

# Filter band
low_freq = 0.02
high_freq = 0.4

for i in np.arange(N_train):
    for j in np.arange(C_train):
       X_train[i,:,j]= filter(X_train[i,:,j],low_freq,high_freq)
for i in np.arange(N_val):
    for j in np.arange(C_val):
       X_val[i,:,j]= filter(X_val[i,:,j],low_freq,high_freq)
    
for i in np.arange(N_test):
    for j in np.arange(C_test):
       X_test[i,:,j]= filter(X_test[i,:,j],low_freq,high_freq)

# %%
# Downsampling in time through FFT

t_sample = 50
X_train_sub = signal.resample(X_train,t_sample,axis=1)
if (N_val > 0): X_val_sub = signal.resample(X_val,t_sample,axis=1)
X_test_sub = signal.resample(X_test,t_sample,axis=1)

# show a downsampling example
plt.plot(np.linspace(0,1,T_train),X_train[5,:,5],'-b')
plt.plot(np.linspace(0,1,t_sample),X_train_sub[5,:,5],'-r')

# %%
print(X_train_sub.shape)
# Out:
# (90, 50, 701)

# %%
# # normalize data across the time sequence dimension only
# scaler = preprocessing.MinMaxScaler()
# for i in range(N_train):
#     scaler.fit(X_train[i,:,:])
#     X_train[i,:,:] = scaler.transform(X_train[i,:,:])
    
# for i in range(N_val):
#     scaler.fit(X_val[i,:,:])
#     X_val[i,:,:] = scaler.transform(X_val[i,:,:])

# %%
# def downsample(data, mul=10, enableTrunc = False):
#     assert data.shape[0] % mul == 0 or  enableTrunc, "Can't downsample without data truncation.\
#                                                 \n Set another value of mul or set enableTrunc = True"
#     outdata = []
#     for i in range(data.shape[0]//mul):
#         outdata.append(np.mean(data[i*mul:(i+1)*mul,...], axis=0, keepdims=True))
#     outdata = reduce(lambda a,b: np.append(a,b,0), outdata)
    
#     return outdata
# span = 2
# X_train_sub = np.expand_dims(downsample(X_train[0,:,:], mul=span),axis=0)
# for n in np.arange(1,X_train.shape[0]):
#     X_train_sub = np.append(X_train_sub,
#                             np.expand_dims(downsample(X_train[n,:,:], mul=span),axis=0),axis=0)

# X_val_sub = np.expand_dims(downsample(X_val[0,:,:], mul=span),axis=0)
# for n in np.arange(1,X_val.shape[0]):
#     X_val_sub = np.append(X_val_sub,
#                             np.expand_dims(downsample(X_val[n,:,:], mul=span),axis=0),axis=0)

# print('X_train_sub: ', X_train_sub.shape)
# print('X_val_sub: ', X_val_sub.shape)

# %%
# Expected input shape: ([batch_size], timesteps, data_dim)
# Note that we have to provide the full batch_input_shape if the network is stateful.
# the sample of index i in batch k is the follow-up for the sample i in batch k-1.

# perhaps should try masking layer

data_dim = C_train
seq_split = 1 # Set to one when using FFT to down sample
seq_len = int(X_train_sub.shape[1]*seq_split)
timesteps = seq_len
num_classes = 4
batch_size = 200
num_epoch = 100

model = Sequential()
#1
model.add(LSTM(200, return_sequences=True, stateful=False,
          recurrent_dropout=0.6, dropout = 0.6, input_shape=(timesteps, data_dim)))

#2
model.add(LSTM(100, return_sequences=True, stateful=False,
          recurrent_dropout=0.5, dropout = 0.5))

#3
model.add(LSTM(50, return_sequences=True, stateful=False,
          recurrent_dropout=0.4, dropout = 0.4))
model.add(Flatten())

#4
model.add(Dense(100))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.5))

#5
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# define early stopping callback
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=30, mode='auto')

# saves the model weights after each epoch if the validation loss decreased
checkpointer = ModelCheckpoint(filepath=f'/Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_{dataset_name}.hdf5', monitor='val_acc', verbose=1)#, initial_value_threshold=0.4)

callbacks_list = [earlystop, checkpointer]

# %%
history = model.fit(X_train_sub[:,:seq_len,:], y_train,
                    batch_size=batch_size, epochs=num_epoch, shuffle=True,
                    validation_split = 0.15, callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.9067 - accuracy: 0.3026
# Epoch 1: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 4s 4s/step - loss: 1.9067 - accuracy: 0.3026 - val_loss: 1.4358 - val_accuracy: 0.2143
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7345 - accuracy: 0.3289
# /Users/almacuevas/work_projects/voting_system_platform/env_voting_system_platform/lib/python3.10/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 213ms/step - loss: 1.7345 - accuracy: 0.3289 - val_loss: 1.4686 - val_accuracy: 0.1429
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5856 - accuracy: 0.4474
# Epoch 3: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 425ms/step - loss: 1.5856 - accuracy: 0.4474 - val_loss: 1.5023 - val_accuracy: 0.1429
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4458 - accuracy: 0.4868
# Epoch 4: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 417ms/step - loss: 1.4458 - accuracy: 0.4868 - val_loss: 1.5070 - val_accuracy: 0.2143
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4007 - accuracy: 0.4079
# Epoch 5: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 470ms/step - loss: 1.4007 - accuracy: 0.4079 - val_loss: 1.5560 - val_accuracy: 0.0714
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1266 - accuracy: 0.5000
# Epoch 6: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 485ms/step - loss: 1.1266 - accuracy: 0.5000 - val_loss: 1.5658 - val_accuracy: 0.1429
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3244 - accuracy: 0.5395
# Epoch 7: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 486ms/step - loss: 1.3244 - accuracy: 0.5395 - val_loss: 1.5979 - val_accuracy: 0.0714
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1388 - accuracy: 0.5526
# Epoch 8: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 484ms/step - loss: 1.1388 - accuracy: 0.5526 - val_loss: 1.6585 - val_accuracy: 0.1429
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0457 - accuracy: 0.5263
# Epoch 9: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 474ms/step - loss: 1.0457 - accuracy: 0.5263 - val_loss: 1.6649 - val_accuracy: 0.1429
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7636 - accuracy: 0.7237
# Epoch 10: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 495ms/step - loss: 0.7636 - accuracy: 0.7237 - val_loss: 1.7033 - val_accuracy: 0.0714
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8845 - accuracy: 0.6316
# Epoch 11: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 500ms/step - loss: 0.8845 - accuracy: 0.6316 - val_loss: 1.6939 - val_accuracy: 0.1429
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7572 - accuracy: 0.6842
# Epoch 12: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 1s 501ms/step - loss: 0.7572 - accuracy: 0.6842 - val_loss: 1.6846 - val_accuracy: 0.0714
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7911 - accuracy: 0.6842
# Epoch 13: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 1s 509ms/step - loss: 0.7911 - accuracy: 0.6842 - val_loss: 1.7185 - val_accuracy: 0.0714
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6254 - accuracy: 0.8026
# Epoch 14: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 1s 504ms/step - loss: 0.6254 - accuracy: 0.8026 - val_loss: 1.6984 - val_accuracy: 0.1429
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6726 - accuracy: 0.7368
# Epoch 15: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 496ms/step - loss: 0.6726 - accuracy: 0.7368 - val_loss: 1.7054 - val_accuracy: 0.2143
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6143 - accuracy: 0.7105
# Epoch 16: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 1s 502ms/step - loss: 0.6143 - accuracy: 0.7105 - val_loss: 1.7163 - val_accuracy: 0.1429
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5414 - accuracy: 0.7763
# Epoch 17: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 499ms/step - loss: 0.5414 - accuracy: 0.7763 - val_loss: 1.7149 - val_accuracy: 0.2143
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4547 - accuracy: 0.8158
# Epoch 18: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 1s 513ms/step - loss: 0.4547 - accuracy: 0.8158 - val_loss: 1.7382 - val_accuracy: 0.1429
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4902 - accuracy: 0.8289
# Epoch 19: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 496ms/step - loss: 0.4902 - accuracy: 0.8289 - val_loss: 1.6969 - val_accuracy: 0.2143
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3903 - accuracy: 0.8158
# Epoch 20: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 496ms/step - loss: 0.3903 - accuracy: 0.8158 - val_loss: 1.7049 - val_accuracy: 0.2143
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5523 - accuracy: 0.7895
# Epoch 21: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 1s 501ms/step - loss: 0.5523 - accuracy: 0.7895 - val_loss: 1.7357 - val_accuracy: 0.2143
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4181 - accuracy: 0.8816
# Epoch 22: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 499ms/step - loss: 0.4181 - accuracy: 0.8816 - val_loss: 1.7090 - val_accuracy: 0.1429
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4508 - accuracy: 0.8421
# Epoch 23: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 1s 515ms/step - loss: 0.4508 - accuracy: 0.8421 - val_loss: 1.7539 - val_accuracy: 0.1429
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.8947
# Epoch 24: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 1s 517ms/step - loss: 0.2337 - accuracy: 0.8947 - val_loss: 1.8019 - val_accuracy: 0.2857
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.9474
# Epoch 25: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 476ms/step - loss: 0.2445 - accuracy: 0.9474 - val_loss: 1.7752 - val_accuracy: 0.2857
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1968 - accuracy: 0.9474
# Epoch 26: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 1s 514ms/step - loss: 0.1968 - accuracy: 0.9474 - val_loss: 1.8161 - val_accuracy: 0.1429
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2130 - accuracy: 0.9474
# Epoch 27: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 1s 505ms/step - loss: 0.2130 - accuracy: 0.9474 - val_loss: 1.8432 - val_accuracy: 0.2143
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3291 - accuracy: 0.8684
# Epoch 28: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 485ms/step - loss: 0.3291 - accuracy: 0.8684 - val_loss: 1.8036 - val_accuracy: 0.2857
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2807 - accuracy: 0.9079
# Epoch 29: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 1s 505ms/step - loss: 0.2807 - accuracy: 0.9079 - val_loss: 1.8298 - val_accuracy: 0.4286
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2405 - accuracy: 0.9079
# Epoch 30: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 499ms/step - loss: 0.2405 - accuracy: 0.9079 - val_loss: 1.9255 - val_accuracy: 0.1429
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3477 - accuracy: 0.8816
# Epoch 31: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model_aguilera_gamified.hdf5
# 1/1 [==============================] - 0s 488ms/step - loss: 0.3477 - accuracy: 0.8816 - val_loss: 1.9276 - val_accuracy: 0.2143

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'],'o')
plt.plot(history.history['val_loss'],'o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evaluate model on entire training set
#model = load_model('/Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/LSTM_model.hdf5')
results = model.evaluate(X_train_sub,y_train,batch_size=N_train)
print("test loss, test acc:", results)
# Out:
# 1/1 [==============================] - 0s 159ms/step - loss: 0.3628 - accuracy: 0.8778
# test loss, test acc: [0.36282557249069214, 0.8777777552604675]

# %%
# evaluate model on test set
results = model.evaluate(X_test_sub,y_test,batch_size=N_test)
print("test loss, test acc:", results)
# Out:
# 1/1 [==============================] - 0s 57ms/step - loss: 2.0813 - accuracy: 0.0833
# test loss, test acc: [2.08129620552063, 0.0833333358168602]

# %%
# TODO: The model is not being saved
