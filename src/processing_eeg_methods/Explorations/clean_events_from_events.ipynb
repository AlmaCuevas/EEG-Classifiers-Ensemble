# %%
from processing_eeg_methods.data_utils import (
    get_dataset_basic_info,
)
from processing_eeg_methods.data_loaders import load_data_labels_based_on_dataset
from processing_eeg_methods.share import datasets_basic_infos

dataset_name = "braincommand"

dataset_info =get_dataset_basic_info(datasets_basic_infos, dataset_name)
data_path = r"C:\Users\rosit\Documents\workprojects\bci_complete\EEG-Classifiers-Ensemble\Datasets\braincommand_dataset"

# %%
import pandas as pd
import numpy as np
from scipy.io import savemat

# %%
def create_event_file(game_mode, y_events_original, subject_id):
    # Initialize the first latency
    prev_latency = 0
    
    # Open the file for writing
    file_name = f'C:\\Users\\rosit\\Documents\\MATLAB\\clean EEG BrainCommand\\cleaned_from_python\\y_{subject_id}_{game_mode}_cleaned_events.txt'
    with open(file_name, 'w') as file:
        # Write the header
        file.write('latency\ttype\tduration\n')
        
        for y_event in y_events_original:
            # Calculate the type value
            latency = prev_latency + 1300
            
            # Write the row to the file
            file.write(f'{latency}\t{y_event}\t1300\n')
            
            # Update the latency for the next row
            prev_latency = latency
    
    print(f'File {file_name} created successfully.')

# %%
game_mode="calibration3" # singleplayer
subject_id_list = [1,8,10,11,12,15,16,19,20,21,22,23,25,26,27,30,31,33,34,35,36,37,38,39,40,41]
#subject_id_list = [1]
for subject_id in subject_id_list:
    _, x_original, y_original = load_data_labels_based_on_dataset(
        dataset_info,
        subject_id,
        data_path,
        game_mode=game_mode,
        normalize=False,
    )
    file_path = fr"C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\datasets_edited\{game_mode}\{subject_id}_{game_mode}_cleaned_events.txt"
    df = pd.read_csv(file_path, sep='\t')
    df['urevent'] = df['urevent'].astype(int)
    indexes = [x - 1 for x in list(df['urevent'])]
    
    y_cleaned = y_original[indexes]
    x_cleaned = x_original[indexes, :,  :]

    create_event_file(game_mode, y_cleaned, subject_id) # to load it in eeglab

    x_cleaned_t = np.transpose(x_cleaned, (1, 2, 0))
    data_dict = {"array": x_cleaned_t}
    data_output_path = r"C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand"
    savemat(fr"{data_output_path}\cleaned_from_python\{subject_id}_{game_mode}_cleaned.mat", data_dict)
    
    labels_dict = {"tags": y_original}
    savemat(fr"{data_output_path}\cleaned_from_python\y_{subject_id}_{game_mode}_cleaned.mat", labels_dict)
# Out:
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_1_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_8_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_10_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_11_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_12_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_15_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_16_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_19_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_20_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_21_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_22_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_23_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_25_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_26_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_27_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_30_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_31_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_33_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_34_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_35_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_36_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_37_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_38_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_39_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_40_calibration3_cleaned_events.txt created successfully.
# label 0 is 57
# label 1 is 57
# label 2 is 57
# label 3 is 57
# Not setting metadata
# 228 matching events found
# Setting baseline interval to [0.0, 1.296] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# File C:\Users\rosit\Documents\MATLAB\clean EEG BrainCommand\cleaned_from_python\y_41_calibration3_cleaned_events.txt created successfully.
