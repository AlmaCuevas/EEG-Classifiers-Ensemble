# %%
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout, TimeDistributed, BatchNormalization, Flatten, Activation
from keras import regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import numpy as np
import h5py
import matplotlib.pyplot as plt
from data_utils import get_data
from sklearn import preprocessing
from functools import reduce
from scipy.fftpack import dct, idct
from scipy import signal

from Code.data_loaders import load_data_labels_based_on_dataset
from share import datasets_basic_infos
from Code.data_utils import train_test_val_split

# %%
# Load data from all .mat files, combine them, eliminate EOG signals, shuffle and
# seperate training data, validation data and testing data.
# Also do mean subtraction on x.


subject_id = 14  # Only two things I should be able to change
dataset_name = 'aguilera'  # Only two things I should be able to change

# Folders and paths
dataset_foldername = dataset_name + '_dataset'
data_path = "/Users/almacuevas/work_projects/voting_system_platform/Datasets/" + dataset_foldername
dataset_info = datasets_basic_infos[dataset_name]

data, label = load_data_labels_based_on_dataset(dataset_name, subject_id, data_path, array_format=True)
# Out:
# Used Annotations descriptions: ['OVTK_StimulationId_Label_01', 'OVTK_StimulationId_Label_02', 'OVTK_StimulationId_Label_03', 'OVTK_StimulationId_Label_04', 'OVTK_StimulationId_Label_05']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 120 events and 701 original time points ...
# 0 bad epochs dropped

# %%
# substract data from list
X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(dataX = data, dataY= label, valid_flag=True)

# get data dimension
N_train, T_train, C_train = X_train.shape
N_val, T_val, C_val = X_val.shape
N_test, T_test, C_test = X_test.shape

# add dummy zeros for y classification
lb = preprocessing.LabelBinarizer()
lb.fit([0, 1, 2, 3,])
lb.classes_
y_train = lb.transform(y_train)
if (N_val > 0): y_val = lb.transform(y_val)
y_test = lb.transform(y_test)

# %%
# Filtering through FFT(discrete cosine transform)

def filter(x, low=0, high=1, plot=False):
    N = x.shape[0]
    t = np.linspace(0,N,N)
    y = dct(x, norm='ortho')
    window = np.zeros(N)
    window[int(low*N):int(high*N)] = 1
    yr = idct(y*window, norm='ortho')
    sum(abs(x-yr)**2) / sum(abs(x)**2)
    if plot:
        plt.plot(t, x, '-b')
        plt.plot(t, yr, 'r')
    return x

# Filter band
low_freq = 0.02
high_freq = 0.4

for i in np.arange(N_train):
    for j in np.arange(C_train):
       X_train[i,:,j]= filter(X_train[i,:,j],low_freq,high_freq)
for i in np.arange(N_val):
    for j in np.arange(C_val):
       X_val[i,:,j]= filter(X_val[i,:,j],low_freq,high_freq)
    
for i in np.arange(N_test):
    for j in np.arange(C_test):
       X_test[i,:,j]= filter(X_test[i,:,j],low_freq,high_freq)

# %%
# Downsampling in time through FFT

t_sample = 50
X_train_sub = signal.resample(X_train,t_sample,axis=1)
if (N_val > 0): X_val_sub = signal.resample(X_val,t_sample,axis=1)
X_test_sub = signal.resample(X_test,t_sample,axis=1)

# show a downsampling example
plt.plot(np.linspace(0,1,T_train),X_train[5,:,5],'-b')
plt.plot(np.linspace(0,1,t_sample),X_train_sub[5,:,5],'-r')

# %%
print(X_train_sub.shape)
# Out:
# (90, 50, 701)

# %%
# # normalize data across the time sequence dimension only
# scaler = preprocessing.MinMaxScaler()
# for i in range(N_train):
#     scaler.fit(X_train[i,:,:])
#     X_train[i,:,:] = scaler.transform(X_train[i,:,:])
    
# for i in range(N_val):
#     scaler.fit(X_val[i,:,:])
#     X_val[i,:,:] = scaler.transform(X_val[i,:,:])

# %%
# def downsample(data, mul=10, enableTrunc = False):
#     assert data.shape[0] % mul == 0 or  enableTrunc, "Can't downsample without data truncation.\
#                                                 \n Set another value of mul or set enableTrunc = True"
#     outdata = []
#     for i in range(data.shape[0]//mul):
#         outdata.append(np.mean(data[i*mul:(i+1)*mul,...], axis=0, keepdims=True))
#     outdata = reduce(lambda a,b: np.append(a,b,0), outdata)
    
#     return outdata
# span = 2
# X_train_sub = np.expand_dims(downsample(X_train[0,:,:], mul=span),axis=0)
# for n in np.arange(1,X_train.shape[0]):
#     X_train_sub = np.append(X_train_sub,
#                             np.expand_dims(downsample(X_train[n,:,:], mul=span),axis=0),axis=0)

# X_val_sub = np.expand_dims(downsample(X_val[0,:,:], mul=span),axis=0)
# for n in np.arange(1,X_val.shape[0]):
#     X_val_sub = np.append(X_val_sub,
#                             np.expand_dims(downsample(X_val[n,:,:], mul=span),axis=0),axis=0)

# print('X_train_sub: ', X_train_sub.shape)
# print('X_val_sub: ', X_val_sub.shape)

# %%
# Expected input shape: ([batch_size], timesteps, data_dim)
# Note that we have to provide the full batch_input_shape if the network is stateful.
# the sample of index i in batch k is the follow-up for the sample i in batch k-1.

# perhaps should try masking layer

data_dim = C_train
seq_split = 1 # Set to one when using FFT to down sample
seq_len = int(X_train_sub.shape[1]*seq_split)
timesteps = seq_len
num_classes = 4
batch_size = 200
num_epoch = 100

model = Sequential()
#1
model.add(LSTM(200, return_sequences=True, stateful=False,
          recurrent_dropout=0.6, dropout = 0.6, input_shape=(timesteps, data_dim)))

#2
model.add(LSTM(100, return_sequences=True, stateful=False,
          recurrent_dropout=0.5, dropout = 0.5))

#3
model.add(LSTM(50, return_sequences=True, stateful=False,
          recurrent_dropout=0.4, dropout = 0.4))
model.add(Flatten())

#4
model.add(Dense(100))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.5))

#5
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# define early stopping callback
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=30, mode='auto')

# saves the model weights after each epoch if the validation loss decreased
checkpointer = ModelCheckpoint(filepath=f'/Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_{dataset_name}.hdf5', monitor='val_acc', verbose=1)#, initial_value_threshold=0.4)

callbacks_list = [earlystop, checkpointer]

# %%
history = model.fit(X_train_sub[:,:seq_len,:], y_train,
                    batch_size=batch_size, epochs=num_epoch, shuffle=True,
                    validation_split = 0.15, callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3840 - accuracy: 0.2895
# Epoch 1: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 1.3840 - accuracy: 0.2895 - val_loss: 0.8177 - val_accuracy: 0.1429
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5918 - accuracy: 0.1053
# /Users/almacuevas/work_projects/voting_system_platform/env_voting_system_platform/lib/python3.10/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 223ms/step - loss: 1.5918 - accuracy: 0.1053 - val_loss: 0.8010 - val_accuracy: 0.2857
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4540 - accuracy: 0.2105
# Epoch 3: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 412ms/step - loss: 1.4540 - accuracy: 0.2105 - val_loss: 0.8285 - val_accuracy: 0.2143
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3397 - accuracy: 0.2895
# Epoch 4: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 495ms/step - loss: 1.3397 - accuracy: 0.2895 - val_loss: 0.8112 - val_accuracy: 0.2857
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3461 - accuracy: 0.3158
# Epoch 5: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 498ms/step - loss: 1.3461 - accuracy: 0.3158 - val_loss: 0.8646 - val_accuracy: 0.1429
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3100 - accuracy: 0.2632
# Epoch 6: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 527ms/step - loss: 1.3100 - accuracy: 0.2632 - val_loss: 0.8624 - val_accuracy: 0.2143
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3095 - accuracy: 0.2763
# Epoch 7: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 499ms/step - loss: 1.3095 - accuracy: 0.2763 - val_loss: 0.7990 - val_accuracy: 0.2143
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2625 - accuracy: 0.3026
# Epoch 8: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 528ms/step - loss: 1.2625 - accuracy: 0.3026 - val_loss: 0.7697 - val_accuracy: 0.3571
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2409 - accuracy: 0.2237
# Epoch 9: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 684ms/step - loss: 1.2409 - accuracy: 0.2237 - val_loss: 0.7666 - val_accuracy: 0.2857
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2147 - accuracy: 0.2895
# Epoch 10: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 498ms/step - loss: 1.2147 - accuracy: 0.2895 - val_loss: 0.7694 - val_accuracy: 0.2143
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3058 - accuracy: 0.1842
# Epoch 11: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 481ms/step - loss: 1.3058 - accuracy: 0.1842 - val_loss: 0.7818 - val_accuracy: 0.2143
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2762 - accuracy: 0.2632
# Epoch 12: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 495ms/step - loss: 1.2762 - accuracy: 0.2632 - val_loss: 0.8122 - val_accuracy: 0.2143
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1917 - accuracy: 0.3158
# Epoch 13: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 486ms/step - loss: 1.1917 - accuracy: 0.3158 - val_loss: 0.7834 - val_accuracy: 0.2143
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.4327 - accuracy: 0.1842
# Epoch 14: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 486ms/step - loss: 1.4327 - accuracy: 0.1842 - val_loss: 0.7736 - val_accuracy: 0.2143
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2334 - accuracy: 0.2895
# Epoch 15: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 490ms/step - loss: 1.2334 - accuracy: 0.2895 - val_loss: 0.7678 - val_accuracy: 0.2143
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1882 - accuracy: 0.1974
# Epoch 16: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 484ms/step - loss: 1.1882 - accuracy: 0.1974 - val_loss: 0.8193 - val_accuracy: 0.2143
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3393 - accuracy: 0.2895
# Epoch 17: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 482ms/step - loss: 1.3393 - accuracy: 0.2895 - val_loss: 0.7905 - val_accuracy: 0.1429
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1450 - accuracy: 0.3026
# Epoch 18: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 491ms/step - loss: 1.1450 - accuracy: 0.3026 - val_loss: 0.7718 - val_accuracy: 0.2857
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1527 - accuracy: 0.2895
# Epoch 19: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 516ms/step - loss: 1.1527 - accuracy: 0.2895 - val_loss: 0.7646 - val_accuracy: 0.2857
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2184 - accuracy: 0.2237
# Epoch 20: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 572ms/step - loss: 1.2184 - accuracy: 0.2237 - val_loss: 0.7441 - val_accuracy: 0.2857
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1357 - accuracy: 0.2763
# Epoch 21: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 501ms/step - loss: 1.1357 - accuracy: 0.2763 - val_loss: 0.7390 - val_accuracy: 0.2857
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2739 - accuracy: 0.2368
# Epoch 22: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 503ms/step - loss: 1.2739 - accuracy: 0.2368 - val_loss: 0.7426 - val_accuracy: 0.2857
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0743 - accuracy: 0.3289
# Epoch 23: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 494ms/step - loss: 1.0743 - accuracy: 0.3289 - val_loss: 0.7584 - val_accuracy: 0.1429
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3007 - accuracy: 0.2105
# Epoch 24: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 501ms/step - loss: 1.3007 - accuracy: 0.2105 - val_loss: 0.7573 - val_accuracy: 0.2143
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0148 - accuracy: 0.2895
# Epoch 25: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 817ms/step - loss: 1.0148 - accuracy: 0.2895 - val_loss: 0.7932 - val_accuracy: 0.2857
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1120 - accuracy: 0.2895
# Epoch 26: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 517ms/step - loss: 1.1120 - accuracy: 0.2895 - val_loss: 0.7809 - val_accuracy: 0.2857
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1355 - accuracy: 0.3158
# Epoch 27: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 507ms/step - loss: 1.1355 - accuracy: 0.3158 - val_loss: 0.7723 - val_accuracy: 0.2857
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3064 - accuracy: 0.1842
# Epoch 28: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 464ms/step - loss: 1.3064 - accuracy: 0.1842 - val_loss: 0.7854 - val_accuracy: 0.2857
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3768 - accuracy: 0.1974
# Epoch 29: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 515ms/step - loss: 1.3768 - accuracy: 0.1974 - val_loss: 0.7425 - val_accuracy: 0.2857
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9955 - accuracy: 0.2632
# Epoch 30: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 637ms/step - loss: 0.9955 - accuracy: 0.2632 - val_loss: 0.7421 - val_accuracy: 0.2857
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0556 - accuracy: 0.2632
# Epoch 31: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 579ms/step - loss: 1.0556 - accuracy: 0.2632 - val_loss: 0.7532 - val_accuracy: 0.2857
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1481 - accuracy: 0.2368
# Epoch 32: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 686ms/step - loss: 1.1481 - accuracy: 0.2368 - val_loss: 0.7724 - val_accuracy: 0.1429
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2486 - accuracy: 0.2237
# Epoch 33: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 473ms/step - loss: 1.2486 - accuracy: 0.2237 - val_loss: 0.7520 - val_accuracy: 0.1429
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1076 - accuracy: 0.2237
# Epoch 34: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 516ms/step - loss: 1.1076 - accuracy: 0.2237 - val_loss: 0.7396 - val_accuracy: 0.2857
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1994 - accuracy: 0.2500
# Epoch 35: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 518ms/step - loss: 1.1994 - accuracy: 0.2500 - val_loss: 0.7634 - val_accuracy: 0.1429
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0642 - accuracy: 0.3421
# Epoch 36: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 490ms/step - loss: 1.0642 - accuracy: 0.3421 - val_loss: 0.7559 - val_accuracy: 0.2143
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1095 - accuracy: 0.2895
# Epoch 37: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 516ms/step - loss: 1.1095 - accuracy: 0.2895 - val_loss: 0.7229 - val_accuracy: 0.2857
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1546 - accuracy: 0.2368
# Epoch 38: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 534ms/step - loss: 1.1546 - accuracy: 0.2368 - val_loss: 0.7260 - val_accuracy: 0.2857
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1463 - accuracy: 0.2763
# Epoch 39: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 731ms/step - loss: 1.1463 - accuracy: 0.2763 - val_loss: 0.7333 - val_accuracy: 0.2857
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3151 - accuracy: 0.2105
# Epoch 40: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 515ms/step - loss: 1.3151 - accuracy: 0.2105 - val_loss: 0.7497 - val_accuracy: 0.2857
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1128 - accuracy: 0.2632
# Epoch 41: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 498ms/step - loss: 1.1128 - accuracy: 0.2632 - val_loss: 0.7591 - val_accuracy: 0.2857
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1420 - accuracy: 0.2895
# Epoch 42: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 495ms/step - loss: 1.1420 - accuracy: 0.2895 - val_loss: 0.7605 - val_accuracy: 0.2857
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1889 - accuracy: 0.1974
# Epoch 43: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 504ms/step - loss: 1.1889 - accuracy: 0.1974 - val_loss: 0.7747 - val_accuracy: 0.2857
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1440 - accuracy: 0.2895
# Epoch 44: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 505ms/step - loss: 1.1440 - accuracy: 0.2895 - val_loss: 0.7757 - val_accuracy: 0.2857
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0819 - accuracy: 0.2763
# Epoch 45: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 513ms/step - loss: 1.0819 - accuracy: 0.2763 - val_loss: 0.7763 - val_accuracy: 0.2857
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2812 - accuracy: 0.2105
# Epoch 46: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 502ms/step - loss: 1.2812 - accuracy: 0.2105 - val_loss: 0.7644 - val_accuracy: 0.2857
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0007 - accuracy: 0.2763
# Epoch 47: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 491ms/step - loss: 1.0007 - accuracy: 0.2763 - val_loss: 0.7781 - val_accuracy: 0.2857
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0875 - accuracy: 0.3684
# Epoch 48: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 525ms/step - loss: 1.0875 - accuracy: 0.3684 - val_loss: 0.7837 - val_accuracy: 0.2857
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1605 - accuracy: 0.2237
# Epoch 49: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 493ms/step - loss: 1.1605 - accuracy: 0.2237 - val_loss: 0.7535 - val_accuracy: 0.2857
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9512 - accuracy: 0.2500
# Epoch 50: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 489ms/step - loss: 0.9512 - accuracy: 0.2500 - val_loss: 0.7483 - val_accuracy: 0.2857
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1145 - accuracy: 0.2500
# Epoch 51: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 495ms/step - loss: 1.1145 - accuracy: 0.2500 - val_loss: 0.7455 - val_accuracy: 0.2857
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1685 - accuracy: 0.2368
# Epoch 52: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 486ms/step - loss: 1.1685 - accuracy: 0.2368 - val_loss: 0.7454 - val_accuracy: 0.2857
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0642 - accuracy: 0.2368
# Epoch 53: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 496ms/step - loss: 1.0642 - accuracy: 0.2368 - val_loss: 0.7523 - val_accuracy: 0.2857
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0697 - accuracy: 0.2895
# Epoch 54: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 499ms/step - loss: 1.0697 - accuracy: 0.2895 - val_loss: 0.7369 - val_accuracy: 0.2857
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1339 - accuracy: 0.2237
# Epoch 55: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 496ms/step - loss: 1.1339 - accuracy: 0.2237 - val_loss: 0.7323 - val_accuracy: 0.2857
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1633 - accuracy: 0.2105
# Epoch 56: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 497ms/step - loss: 1.1633 - accuracy: 0.2105 - val_loss: 0.7542 - val_accuracy: 0.2857
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1473 - accuracy: 0.2105
# Epoch 57: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 492ms/step - loss: 1.1473 - accuracy: 0.2105 - val_loss: 0.7381 - val_accuracy: 0.2857
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0522 - accuracy: 0.2237
# Epoch 58: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 506ms/step - loss: 1.0522 - accuracy: 0.2237 - val_loss: 0.7253 - val_accuracy: 0.2857
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9880 - accuracy: 0.3421
# Epoch 59: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 497ms/step - loss: 0.9880 - accuracy: 0.3421 - val_loss: 0.7098 - val_accuracy: 0.2857
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0611 - accuracy: 0.2895
# Epoch 60: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 489ms/step - loss: 1.0611 - accuracy: 0.2895 - val_loss: 0.7345 - val_accuracy: 0.1429
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0621 - accuracy: 0.2368
# Epoch 61: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 511ms/step - loss: 1.0621 - accuracy: 0.2368 - val_loss: 0.7533 - val_accuracy: 0.1429
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 1.2470 - accuracy: 0.2237
# Epoch 62: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 503ms/step - loss: 1.2470 - accuracy: 0.2237 - val_loss: 0.8127 - val_accuracy: 0.1429
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0668 - accuracy: 0.3026
# Epoch 63: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 505ms/step - loss: 1.0668 - accuracy: 0.3026 - val_loss: 0.8201 - val_accuracy: 0.1429
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0546 - accuracy: 0.2500
# Epoch 64: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 506ms/step - loss: 1.0546 - accuracy: 0.2500 - val_loss: 0.8430 - val_accuracy: 0.1429
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0301 - accuracy: 0.2895
# Epoch 65: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 512ms/step - loss: 1.0301 - accuracy: 0.2895 - val_loss: 0.8320 - val_accuracy: 0.1429
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0022 - accuracy: 0.3289
# Epoch 66: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 510ms/step - loss: 1.0022 - accuracy: 0.3289 - val_loss: 0.7855 - val_accuracy: 0.1429
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1175 - accuracy: 0.2368
# Epoch 67: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 503ms/step - loss: 1.1175 - accuracy: 0.2368 - val_loss: 0.7937 - val_accuracy: 0.1429
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0643 - accuracy: 0.2895
# Epoch 68: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 511ms/step - loss: 1.0643 - accuracy: 0.2895 - val_loss: 0.7998 - val_accuracy: 0.1429
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9819 - accuracy: 0.2763
# Epoch 69: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 520ms/step - loss: 0.9819 - accuracy: 0.2763 - val_loss: 0.7882 - val_accuracy: 0.1429
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1694 - accuracy: 0.2368
# Epoch 70: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 497ms/step - loss: 1.1694 - accuracy: 0.2368 - val_loss: 0.7738 - val_accuracy: 0.1429
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0859 - accuracy: 0.2237
# Epoch 71: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 521ms/step - loss: 1.0859 - accuracy: 0.2237 - val_loss: 0.8455 - val_accuracy: 0.1429
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1109 - accuracy: 0.2500
# Epoch 72: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 515ms/step - loss: 1.1109 - accuracy: 0.2500 - val_loss: 0.9189 - val_accuracy: 0.1429
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0839 - accuracy: 0.2105
# Epoch 73: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 520ms/step - loss: 1.0839 - accuracy: 0.2105 - val_loss: 0.7608 - val_accuracy: 0.2143
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1511 - accuracy: 0.2368
# Epoch 74: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 508ms/step - loss: 1.1511 - accuracy: 0.2368 - val_loss: 0.7370 - val_accuracy: 0.2857
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.7586 - accuracy: 0.3684
# Epoch 75: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 528ms/step - loss: 0.7586 - accuracy: 0.3684 - val_loss: 0.7340 - val_accuracy: 0.2857
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0632 - accuracy: 0.2500
# Epoch 76: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 488ms/step - loss: 1.0632 - accuracy: 0.2500 - val_loss: 0.7661 - val_accuracy: 0.1429
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0601 - accuracy: 0.2500
# Epoch 77: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 486ms/step - loss: 1.0601 - accuracy: 0.2500 - val_loss: 0.8175 - val_accuracy: 0.1429
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0442 - accuracy: 0.2500
# Epoch 78: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 525ms/step - loss: 1.0442 - accuracy: 0.2500 - val_loss: 0.7214 - val_accuracy: 0.2857
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0512 - accuracy: 0.2763
# Epoch 79: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 512ms/step - loss: 1.0512 - accuracy: 0.2763 - val_loss: 0.7984 - val_accuracy: 0.1429
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9559 - accuracy: 0.3421
# Epoch 80: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 0s 490ms/step - loss: 0.9559 - accuracy: 0.3421 - val_loss: 0.7662 - val_accuracy: 0.1429
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 1.1541 - accuracy: 0.1447
# Epoch 81: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 524ms/step - loss: 1.1541 - accuracy: 0.1447 - val_loss: 0.7117 - val_accuracy: 0.1429
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9465 - accuracy: 0.2895
# Epoch 82: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 540ms/step - loss: 0.9465 - accuracy: 0.2895 - val_loss: 0.7465 - val_accuracy: 0.1429
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0368 - accuracy: 0.2237
# Epoch 83: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 504ms/step - loss: 1.0368 - accuracy: 0.2237 - val_loss: 0.7427 - val_accuracy: 0.2857
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0180 - accuracy: 0.2895
# Epoch 84: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 517ms/step - loss: 1.0180 - accuracy: 0.2895 - val_loss: 0.7379 - val_accuracy: 0.2143
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0526 - accuracy: 0.2895
# Epoch 85: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 522ms/step - loss: 1.0526 - accuracy: 0.2895 - val_loss: 0.7604 - val_accuracy: 0.1429
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9147 - accuracy: 0.3684
# Epoch 86: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 526ms/step - loss: 0.9147 - accuracy: 0.3684 - val_loss: 0.7450 - val_accuracy: 0.2143
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8186 - accuracy: 0.3553
# Epoch 87: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 507ms/step - loss: 0.8186 - accuracy: 0.3553 - val_loss: 0.7471 - val_accuracy: 0.2143
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0728 - accuracy: 0.2105
# Epoch 88: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 722ms/step - loss: 1.0728 - accuracy: 0.2105 - val_loss: 0.7751 - val_accuracy: 0.2143
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9243 - accuracy: 0.3553
# Epoch 89: saving model to /Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model_aguilera.hdf5
# 1/1 [==============================] - 1s 580ms/step - loss: 0.9243 - accuracy: 0.3553 - val_loss: 0.7873 - val_accuracy: 0.2143

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'],'o')
plt.plot(history.history['val_loss'],'o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evaluate model on entire training set
model = load_model('/Users/almacuevas/work_projects/voting_system_platform/Code/BigProject/final_code/LSTM_model.hdf5')
results = model.evaluate(X_train_sub,y_train,batch_size=N_train)
print("test loss, test acc:", results)
# Out:
# 1/1 [==============================] - 0s 364ms/step - loss: 0.8733 - accuracy: 0.2667
# test loss, test acc: [0.8732708692550659, 0.2666666805744171]

# %%
# evaluate model on test set
results = model.evaluate(X_test_sub,y_test,batch_size=N_test)
print("test loss, test acc:", results)
# Out:
# 1/1 [==============================] - 0s 299ms/step - loss: 0.9470 - accuracy: 0.2500
# test loss, test acc: [0.9469599723815918, 0.25]

# %%
# TODO: The model is not being saved
