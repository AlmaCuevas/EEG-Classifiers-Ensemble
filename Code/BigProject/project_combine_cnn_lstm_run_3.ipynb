# %% [markdown]
# This run has higher dropout, larger size lstm.
#
# This run has validation accuracy around 70%+
#
# From results shown, high dropout does contribute to regularization. Compared to the first run, validation accuracy doesn't improve, however the training history is less oscillatory.

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, Activation, Flatten
from keras.utils import to_categorical
import numpy as np
import h5py
import matplotlib.pyplot as plt
from data_utils import get_data
from sklearn import preprocessing

from Code.data_loaders import load_data_labels_based_on_dataset
from share import datasets_basic_infos
from Code.data_utils import train_test_val_split

# %%
subject_id = 1  # Only two things I should be able to change
dataset_name = 'aguilera'  # Only two things I should be able to change

# Folders and paths
dataset_foldername = dataset_name + '_dataset'
data_path = "/Users/almacuevas/work_projects/voting_system_platform/Datasets/" + dataset_foldername
dataset_info = datasets_basic_infos[dataset_name]

data, label = load_data_labels_based_on_dataset(dataset_name, subject_id, data_path, array_format=True)
label = label -1
# Out:
# Used Annotations descriptions: ['OVTK_StimulationId_Label_01', 'OVTK_StimulationId_Label_02', 'OVTK_StimulationId_Label_03', 'OVTK_StimulationId_Label_04', 'OVTK_StimulationId_Label_05']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 120 events and 701 original time points ...
# 0 bad epochs dropped

# %%
num_classes = 4

# substract data from list
X_train, X_test, X_val, y_train, y_test, y_val = train_test_val_split(dataX = data, dataY= label, valid_flag=True)

# get data dimension
N_train, T_train, C_train = X_train.shape
N_val, T_val, C_val = X_val.shape
N_test, T_test, C_test = X_test.shape

y_test
# Out:
# array([1, 0, 1, 1, 3, 2, 3, 2, 0, 2, 1, 1])

# %%
# add dummy zeros for y classification, convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_val = to_categorical(y_val, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
# construct X_total and y_total based on sub-sampling of X_train and y_train

# take sub-sampling on the time sequence to reduce dimension for RNN
sampling = 1

X_train = X_train.reshape(N_train,int(T_train/sampling), sampling, C_train)[:,:,0,:]
X_val = X_val.reshape(N_val,int(T_val/sampling), sampling, C_val)[:,:,0,:]
X_test = X_test.reshape(N_test,int(T_test/sampling), sampling, C_test)[:,:,0,:]

# get new data dimension
N_train, T_train, C_train = X_train.shape
N_val, T_val, C_val = X_val.shape
N_test, T_test, C_test = X_test.shape

print('X_train: ', X_train.shape)
print('y_train: ', y_train.shape)
print('X_val: ', X_val.shape)
print('y_val: ', y_val.shape)
print('X_test: ', X_test.shape)
print('y_test: ', y_test.shape)
# Out:
# X_train:  (90, 22, 701)
# y_train:  (90, 4)
# X_val:  (18, 22, 701)
# y_val:  (18, 4)
# X_test:  (12, 22, 701)
# y_test:  (12, 4)

# %%
# Expected input batch shape: (batch_size, timesteps, data_dim)
# Note that we have to provide the full batch_input_shape since the network is stateful.
# the sample of index i in batch k is the follow-up for the sample i in batch k-1.

# perhaps should try masking layer

data_dim = C_train
timesteps = T_train
batch_size = y_train.shape[0]
num_epoch = y_train.shape[0]

# make a sequential model
model = Sequential()

# add 1-layer cnn
model.add(Conv1D(40, kernel_size=20, strides=4,
          input_shape=(timesteps, data_dim)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(BatchNormalization())
#model.add(MaxPooling1D(pool_size=4, strides=4))


# add 2-layer lstm
model.add(LSTM(30, return_sequences=True, stateful=False))
model.add(Dropout(0.5))
model.add(BatchNormalization())
model.add(LSTM(20, return_sequences=True, stateful=False))
model.add(Dropout(0.5))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))

# set loss function and optimizer
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# train the data with validation
history = model.fit(X_train, y_train,
                    batch_size=batch_size, 
                    epochs=num_epoch, 
                    shuffle=False,
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/90
# 1/1 [==============================] - 2s 2s/step - loss: 2.1884 - accuracy: 0.1889 - val_loss: 1.4006 - val_accuracy: 0.1111
# Epoch 2/90
# 1/1 [==============================] - 0s 21ms/step - loss: 1.9459 - accuracy: 0.2667 - val_loss: 1.4035 - val_accuracy: 0.1667
# Epoch 3/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8259 - accuracy: 0.2778 - val_loss: 1.3820 - val_accuracy: 0.3333
# Epoch 4/90
# 1/1 [==============================] - 0s 22ms/step - loss: 1.9837 - accuracy: 0.3000 - val_loss: 1.3770 - val_accuracy: 0.3333
# Epoch 5/90
# 1/1 [==============================] - 0s 19ms/step - loss: 2.1233 - accuracy: 0.1889 - val_loss: 1.3819 - val_accuracy: 0.3333
# Epoch 6/90
# 1/1 [==============================] - 0s 19ms/step - loss: 2.0136 - accuracy: 0.2222 - val_loss: 1.3862 - val_accuracy: 0.3333
# Epoch 7/90
# 1/1 [==============================] - 0s 18ms/step - loss: 1.8540 - accuracy: 0.2889 - val_loss: 1.3956 - val_accuracy: 0.1111
# Epoch 8/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.7009 - accuracy: 0.3556 - val_loss: 1.3979 - val_accuracy: 0.2222
# Epoch 9/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.9518 - accuracy: 0.2111 - val_loss: 1.3935 - val_accuracy: 0.2778
# Epoch 10/90
# 1/1 [==============================] - 0s 21ms/step - loss: 2.1094 - accuracy: 0.1778 - val_loss: 1.3918 - val_accuracy: 0.3333
# Epoch 11/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7973 - accuracy: 0.2556 - val_loss: 1.3922 - val_accuracy: 0.3333
# Epoch 12/90
# 1/1 [==============================] - 0s 19ms/step - loss: 2.1618 - accuracy: 0.1556 - val_loss: 1.3936 - val_accuracy: 0.3333
# Epoch 13/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.9545 - accuracy: 0.2667 - val_loss: 1.3956 - val_accuracy: 0.3333
# Epoch 14/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.9268 - accuracy: 0.2556 - val_loss: 1.3978 - val_accuracy: 0.3333
# Epoch 15/90
# 1/1 [==============================] - 0s 21ms/step - loss: 1.7970 - accuracy: 0.2889 - val_loss: 1.4000 - val_accuracy: 0.2778
# Epoch 16/90
# 1/1 [==============================] - 0s 21ms/step - loss: 1.7446 - accuracy: 0.3000 - val_loss: 1.4026 - val_accuracy: 0.2778
# Epoch 17/90
# 1/1 [==============================] - 0s 21ms/step - loss: 1.8225 - accuracy: 0.2222 - val_loss: 1.4041 - val_accuracy: 0.1111
# Epoch 18/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.8468 - accuracy: 0.2889 - val_loss: 1.4059 - val_accuracy: 0.1111
# Epoch 19/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7943 - accuracy: 0.2556 - val_loss: 1.4080 - val_accuracy: 0.1111
# Epoch 20/90
# 1/1 [==============================] - 0s 32ms/step - loss: 1.8532 - accuracy: 0.2333 - val_loss: 1.4103 - val_accuracy: 0.1111
# Epoch 21/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.8502 - accuracy: 0.2556 - val_loss: 1.4124 - val_accuracy: 0.1111
# Epoch 22/90
# 1/1 [==============================] - 0s 22ms/step - loss: 1.7610 - accuracy: 0.2667 - val_loss: 1.4145 - val_accuracy: 0.1111
# Epoch 23/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.7975 - accuracy: 0.1889 - val_loss: 1.4164 - val_accuracy: 0.1111
# Epoch 24/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7668 - accuracy: 0.2444 - val_loss: 1.4184 - val_accuracy: 0.1111
# Epoch 25/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.9542 - accuracy: 0.2111 - val_loss: 1.4200 - val_accuracy: 0.0556
# Epoch 26/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.6643 - accuracy: 0.2556 - val_loss: 1.4216 - val_accuracy: 0.1111
# Epoch 27/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7752 - accuracy: 0.2667 - val_loss: 1.4229 - val_accuracy: 0.1111
# Epoch 28/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.7936 - accuracy: 0.2778 - val_loss: 1.4241 - val_accuracy: 0.0556
# Epoch 29/90
# 1/1 [==============================] - 0s 22ms/step - loss: 1.8518 - accuracy: 0.2222 - val_loss: 1.4254 - val_accuracy: 0.1111
# Epoch 30/90
# 1/1 [==============================] - 0s 23ms/step - loss: 1.5108 - accuracy: 0.3333 - val_loss: 1.4266 - val_accuracy: 0.1111
# Epoch 31/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8283 - accuracy: 0.2222 - val_loss: 1.4278 - val_accuracy: 0.1111
# Epoch 32/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7149 - accuracy: 0.2667 - val_loss: 1.4289 - val_accuracy: 0.1111
# Epoch 33/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8392 - accuracy: 0.2556 - val_loss: 1.4300 - val_accuracy: 0.1111
# Epoch 34/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.6803 - accuracy: 0.2889 - val_loss: 1.4311 - val_accuracy: 0.1111
# Epoch 35/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8845 - accuracy: 0.2444 - val_loss: 1.4321 - val_accuracy: 0.1111
# Epoch 36/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.8456 - accuracy: 0.2222 - val_loss: 1.4332 - val_accuracy: 0.1111
# Epoch 37/90
# 1/1 [==============================] - 0s 21ms/step - loss: 1.6426 - accuracy: 0.3333 - val_loss: 1.4344 - val_accuracy: 0.1111
# Epoch 38/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7639 - accuracy: 0.3000 - val_loss: 1.4355 - val_accuracy: 0.1111
# Epoch 39/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.9336 - accuracy: 0.2111 - val_loss: 1.4366 - val_accuracy: 0.1111
# Epoch 40/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.9248 - accuracy: 0.2111 - val_loss: 1.4376 - val_accuracy: 0.1111
# Epoch 41/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.9767 - accuracy: 0.1889 - val_loss: 1.4384 - val_accuracy: 0.1111
# Epoch 42/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7586 - accuracy: 0.2889 - val_loss: 1.4391 - val_accuracy: 0.1111
# Epoch 43/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7347 - accuracy: 0.1778 - val_loss: 1.4397 - val_accuracy: 0.1111
# Epoch 44/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.8714 - accuracy: 0.2000 - val_loss: 1.4404 - val_accuracy: 0.1111
# Epoch 45/90
# 1/1 [==============================] - 0s 18ms/step - loss: 1.9590 - accuracy: 0.2111 - val_loss: 1.4409 - val_accuracy: 0.1111
# Epoch 46/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.7498 - accuracy: 0.2667 - val_loss: 1.4414 - val_accuracy: 0.1111
# Epoch 47/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.6584 - accuracy: 0.3111 - val_loss: 1.4418 - val_accuracy: 0.1111
# Epoch 48/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.5847 - accuracy: 0.2222 - val_loss: 1.4420 - val_accuracy: 0.1111
# Epoch 49/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.6372 - accuracy: 0.2667 - val_loss: 1.4423 - val_accuracy: 0.1111
# Epoch 50/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.6656 - accuracy: 0.3667 - val_loss: 1.4424 - val_accuracy: 0.1111
# Epoch 51/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7857 - accuracy: 0.2778 - val_loss: 1.4427 - val_accuracy: 0.1111
# Epoch 52/90
# 1/1 [==============================] - 0s 21ms/step - loss: 1.7606 - accuracy: 0.2222 - val_loss: 1.4429 - val_accuracy: 0.1111
# Epoch 53/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.6468 - accuracy: 0.2778 - val_loss: 1.4433 - val_accuracy: 0.1111
# Epoch 54/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.7535 - accuracy: 0.1778 - val_loss: 1.4437 - val_accuracy: 0.1111
# Epoch 55/90
# 1/1 [==============================] - 0s 23ms/step - loss: 1.7882 - accuracy: 0.2222 - val_loss: 1.4442 - val_accuracy: 0.1111
# Epoch 56/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.5163 - accuracy: 0.3444 - val_loss: 1.4445 - val_accuracy: 0.1111
# Epoch 57/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.5903 - accuracy: 0.2333 - val_loss: 1.4448 - val_accuracy: 0.1111
# Epoch 58/90
# 1/1 [==============================] - 0s 21ms/step - loss: 1.7333 - accuracy: 0.2333 - val_loss: 1.4453 - val_accuracy: 0.1111
# Epoch 59/90
# 1/1 [==============================] - 0s 18ms/step - loss: 1.9310 - accuracy: 0.1889 - val_loss: 1.4458 - val_accuracy: 0.1111
# Epoch 60/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.5899 - accuracy: 0.3333 - val_loss: 1.4463 - val_accuracy: 0.1111
# Epoch 61/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7754 - accuracy: 0.2556 - val_loss: 1.4467 - val_accuracy: 0.1111
# Epoch 62/90
# 1/1 [==============================] - 0s 21ms/step - loss: 1.6646 - accuracy: 0.2889 - val_loss: 1.4471 - val_accuracy: 0.1111
# Epoch 63/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.5737 - accuracy: 0.2889 - val_loss: 1.4474 - val_accuracy: 0.1111
# Epoch 64/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7928 - accuracy: 0.2222 - val_loss: 1.4478 - val_accuracy: 0.1111
# Epoch 65/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.7589 - accuracy: 0.2444 - val_loss: 1.4482 - val_accuracy: 0.1111
# Epoch 66/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.6970 - accuracy: 0.2889 - val_loss: 1.4486 - val_accuracy: 0.1111
# Epoch 67/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8187 - accuracy: 0.2556 - val_loss: 1.4490 - val_accuracy: 0.1111
# Epoch 68/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.4708 - accuracy: 0.3333 - val_loss: 1.4495 - val_accuracy: 0.1111
# Epoch 69/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8712 - accuracy: 0.1889 - val_loss: 1.4498 - val_accuracy: 0.1111
# Epoch 70/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.6653 - accuracy: 0.2556 - val_loss: 1.4502 - val_accuracy: 0.1111
# Epoch 71/90
# 1/1 [==============================] - 0s 23ms/step - loss: 1.8364 - accuracy: 0.1889 - val_loss: 1.4506 - val_accuracy: 0.1111
# Epoch 72/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.4957 - accuracy: 0.3000 - val_loss: 1.4510 - val_accuracy: 0.1111
# Epoch 73/90
# 1/1 [==============================] - 0s 18ms/step - loss: 1.5805 - accuracy: 0.3111 - val_loss: 1.4513 - val_accuracy: 0.1111
# Epoch 74/90
# 1/1 [==============================] - 0s 18ms/step - loss: 1.7319 - accuracy: 0.2333 - val_loss: 1.4516 - val_accuracy: 0.1111
# Epoch 75/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.6588 - accuracy: 0.2778 - val_loss: 1.4517 - val_accuracy: 0.1111
# Epoch 76/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8284 - accuracy: 0.2111 - val_loss: 1.4517 - val_accuracy: 0.1111
# Epoch 77/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.7060 - accuracy: 0.3444 - val_loss: 1.4517 - val_accuracy: 0.1111
# Epoch 78/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.7112 - accuracy: 0.3333 - val_loss: 1.4514 - val_accuracy: 0.1111
# Epoch 79/90
# 1/1 [==============================] - 0s 21ms/step - loss: 1.7095 - accuracy: 0.2444 - val_loss: 1.4511 - val_accuracy: 0.1111
# Epoch 80/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.7702 - accuracy: 0.2000 - val_loss: 1.4512 - val_accuracy: 0.1111
# Epoch 81/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.6946 - accuracy: 0.2444 - val_loss: 1.4511 - val_accuracy: 0.1111
# Epoch 82/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7263 - accuracy: 0.2222 - val_loss: 1.4509 - val_accuracy: 0.2222
# Epoch 83/90
# 1/1 [==============================] - 0s 21ms/step - loss: 1.5423 - accuracy: 0.3444 - val_loss: 1.4506 - val_accuracy: 0.1667
# Epoch 84/90
# 1/1 [==============================] - 0s 21ms/step - loss: 1.6295 - accuracy: 0.2556 - val_loss: 1.4503 - val_accuracy: 0.1667
# Epoch 85/90
# 1/1 [==============================] - 0s 19ms/step - loss: 1.5161 - accuracy: 0.3222 - val_loss: 1.4499 - val_accuracy: 0.1667
# Epoch 86/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7719 - accuracy: 0.2444 - val_loss: 1.4496 - val_accuracy: 0.1667
# Epoch 87/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.6284 - accuracy: 0.2667 - val_loss: 1.4494 - val_accuracy: 0.1667
# Epoch 88/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7507 - accuracy: 0.2667 - val_loss: 1.4492 - val_accuracy: 0.1667
# Epoch 89/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7812 - accuracy: 0.2000 - val_loss: 1.4490 - val_accuracy: 0.1667
# Epoch 90/90
# 1/1 [==============================] - 0s 20ms/step - loss: 1.6174 - accuracy: 0.2111 - val_loss: 1.4490 - val_accuracy: 0.1667

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'],'o')
plt.plot(history.history['val_loss'],'o')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# test set
results = model.evaluate(X_test,y_test,batch_size=N_test)
print("test loss, test acc:", results)
# Out:
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4370 - accuracy: 0.1667
# test loss, test acc: [1.4369951486587524, 0.1666666716337204]
